# %% [markdown]
# <a href="https://colab.research.google.com/github/deekshithareddygoli/Medicinal-Plants-Identification-using-CNN/blob/main/Medicinal_Plants_Identification_using_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# Importing the Libraries
from tensorflow.keras.preprocessing.image import load_img
import warnings
warnings.filterwarnings("ignore")

import os
import glob
import matplotlib.pyplot as plt
# Keras API
import keras
from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten
from keras.layers import Conv2D,MaxPooling2D,Activation,AveragePooling2D,BatchNormalization
from keras.preprocessing.image import ImageDataGenerator

# %%
# Loading the data
train_dir='/content/drive/MyDrive/Segmented Medicinal Leaf Images/Train Data'
test_dir='/content/drive/MyDrive/Segmented Medicinal Leaf Images/Test Data'

# %%
# Function to get count of images
def get_files(directory):
  if not os.path.exists(directory):
    return 0
  count=0
  for current_path,dirs,files in os.walk(directory):
    for dr in dirs:
      count+= len(glob.glob(os.path.join(current_path,dr+"/*")))
  return count

# %%
# Prints the number of images in training and testing directories
train_samples =get_files(train_dir)
num_classes=len(glob.glob(train_dir+"/*"))
test_samples=get_files(test_dir)
print(num_classes,"Classes")
print(train_samples,"Train images")
print(test_samples,"Test images")
# Out:
# 18 Classes
# 614 Train images
# 435 Test images

# %%
# Preprocessing the training and testing data.
train_datagen=ImageDataGenerator(rescale=1./255,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   validation_split=0.2, # validation split 20%.
                                   horizontal_flip=True)
test_datagen=ImageDataGenerator(rescale=1./255)

# %%
# Set height, width and color of input image.
img_width,img_height =256,256
input_shape=(img_width,img_height,3)
batch_size =32

train_generator =train_datagen.flow_from_directory(train_dir,
                                                   target_size=(img_width,img_height),
                                                   batch_size=batch_size)
test_generator=test_datagen.flow_from_directory(test_dir,shuffle=True, target_size=(img_width,img_height), batch_size=batch_size)
# Out:
# Found 614 images belonging to 18 classes.
# Found 435 images belonging to 12 classes.

# %%
# Building CNN Model
model = Sequential()
model.add(Conv2D(32, (5, 5),input_shape=input_shape,activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Conv2D(32, (3, 3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(32,activation='relu'))
model.add(Dense(num_classes,activation='softmax'))

# %%
# Summary of the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 252, 252, 32)      2432
#
#  max_pooling2d (MaxPooling2  (None, 84, 84, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 82, 82, 32)        9248
#
#  max_pooling2d_1 (MaxPoolin  (None, 41, 41, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 39, 39, 64)        18496
#
#  max_pooling2d_2 (MaxPoolin  (None, 19, 19, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 23104)             0
#
#  dense (Dense)               (None, 64)                1478720
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 18)                594
#
# =================================================================
# Total params: 1511570 (5.77 MB)
# Trainable params: 1511570 (5.77 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Prints the names of all layers present in the model
model_layers = [ layer.name for layer in model.layers]
print('layer name : ',model_layers)
# Out:
# layer name :  ['conv2d', 'max_pooling2d', 'conv2d_1', 'max_pooling2d_1', 'conv2d_2', 'max_pooling2d_2', 'flatten', 'dense', 'dropout', 'dense_1', 'dense_2']

# %%
# Load and Display the Image
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import numpy as np
import matplotlib.pyplot as plt

img1 = load_img('/content/drive/MyDrive/Segmented Medicinal Leaf Images/Train Data/Alpinia Galanga (Rasna)/AG-S-001.jpg')
plt.imshow(img1)

# Preprocess the Image
img1 = load_img(
    '/content/drive/MyDrive/Segmented Medicinal Leaf Images/Train Data/Alpinia Galanga (Rasna)/AG-S-001.jpg', target_size=(256, 256))
img = img_to_array(img1)
img = img / 255
img = np.expand_dims(img, axis=0)

# %%
# Visualizing output after every layer.
from keras.models import Model
conv2d_1_output = Model(inputs=model.input, outputs=model.get_layer('conv2d').output)
max_pooling2d_1_output = Model(inputs=model.input,outputs=model.get_layer('max_pooling2d').output)
conv2d_2_output = Model(inputs=model.input,outputs=model.get_layer('conv2d_1').output)
max_pooling2d_2_output = Model(inputs=model.input,outputs=model.get_layer('max_pooling2d_1').output)
conv2d_3_output = Model(inputs=model.input,outputs=model.get_layer('conv2d_2').output)
max_pooling2d_3_output = Model(inputs=model.input,outputs=model.get_layer('max_pooling2d_2').output)
flatten_1_output = Model(inputs=model.input,outputs=model.get_layer('flatten').output)
conv2d_1_features = conv2d_1_output.predict(img)
max_pooling2d_1_features = max_pooling2d_1_output.predict(img)
conv2d_2_features = conv2d_2_output.predict(img)
max_pooling2d_2_features = max_pooling2d_2_output.predict(img)
conv2d_3_features = conv2d_3_output.predict(img)
max_pooling2d_3_features = max_pooling2d_3_output.predict(img)
flatten_1_features = flatten_1_output.predict(img)
# Out:
# 1/1 [==============================] - 0s 344ms/step
# 1/1 [==============================] - 0s 285ms/step
# 1/1 [==============================] - 0s 427ms/step
# 1/1 [==============================] - 0s 179ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f54fdc54310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 335ms/step
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f54fdc55000> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 373ms/step
# 1/1 [==============================] - 0s 287ms/step

# %%
# Displays the grid of subplots to visualize the output of the first convolutional layer's filters
import matplotlib.image as mpimg

fig=plt.figure(figsize=(14,7))
columns = 8
rows = 4
for i in range(columns*rows):
    #img = mpimg.imread()
    fig.add_subplot(rows, columns, i+1)
    plt.axis('off')
    plt.title('filter'+str(i))
    plt.imshow(conv2d_1_features[0, :, :, i], cmap='viridis') # Visualizing in color mode.
plt.show()

# %%
# Displays the grid of subplots to visualize the output of the first max pooling layer's filters
import matplotlib.image as mpimg

fig=plt.figure(figsize=(14,7))
columns = 8
rows = 4
for i in range(columns*rows):
    #img = mpimg.imread()
    fig.add_subplot(rows, columns, i+1)
    plt.axis('off')
    plt.title('filter'+str(i))
    plt.imshow(max_pooling2d_1_features[0, :, :, i], cmap='viridis')
plt.show()

# %%
# Displays the grid of subplots to visualize the output of the second convolutional layer's filters
import matplotlib.image as mpimg

fig=plt.figure(figsize=(14,7))
columns = 8
rows = 4
for i in range(columns*rows):
    #img = mpimg.imread()
    fig.add_subplot(rows, columns, i+1)
    plt.axis('off')
    plt.title('filter'+str(i))
    plt.imshow(conv2d_2_features[0, :, :, i], cmap='viridis')
plt.show()

# %%
# Displays the grid of subplots to visualize the output of the second max pooling layer's filters
import matplotlib.image as mpimg

fig=plt.figure(figsize=(14,7))
columns = 8
rows = 4
for i in range(columns*rows):
    #img = mpimg.imread()
    fig.add_subplot(rows, columns, i+1)
    plt.axis('off')
    plt.title('filter'+str(i))
    plt.imshow(max_pooling2d_2_features[0, :, :, i], cmap='viridis')
plt.show()

# %%
# Displays the grid of subplots to visualize the output of the third convolutional layer's filters
import matplotlib.image as mpimg

fig=plt.figure(figsize=(16,16))
columns =8
rows = 8
for i in range(columns*rows):
    #img = mpimg.imread()
    fig.add_subplot(rows, columns, i+1)
    plt.axis('off')
    plt.title('filter'+str(i))
    plt.imshow(conv2d_3_features[0, :, :, i], cmap='viridis')
plt.show()

# %%
# Displays the grid of subplots to visualize the output of the third max pooling layer's filters
import matplotlib.image as mpimg

fig=plt.figure(figsize=(14,14))
columns = 8
rows = 8
for i in range(columns*rows):
    #img = mpimg.imread()
    fig.add_subplot(rows, columns, i+1)
    plt.axis('off')
    plt.title('filter'+str(i))
    plt.imshow(max_pooling2d_3_features[0, :, :, i],cmap='viridis')
plt.show()

# %%
# Validation data.
validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size)
# Out:
# Found 614 images belonging to 18 classes.

# %%
# Training the data.
opt = keras.optimizers.Adam(lr=0.001)
model.compile(optimizer=opt, loss='categorical_crossentropy',
              metrics=['accuracy'])
train = model.fit_generator(train_generator,
                            epochs=75,
                            steps_per_epoch=train_generator.samples // batch_size,
                            validation_data=validation_generator,
                            validation_steps=validation_generator.samples // batch_size,
                            verbose=1)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/75
# 19/19 [==============================] - 357s 19s/step - loss: 2.9142 - accuracy: 0.0687 - val_loss: 2.8650 - val_accuracy: 0.0609
# Epoch 2/75
# 19/19 [==============================] - 90s 5s/step - loss: 2.8507 - accuracy: 0.0945 - val_loss: 2.7948 - val_accuracy: 0.1562
# Epoch 3/75
# 19/19 [==============================] - 99s 5s/step - loss: 2.6251 - accuracy: 0.1735 - val_loss: 2.3291 - val_accuracy: 0.2418
# Epoch 4/75
# 19/19 [==============================] - 90s 5s/step - loss: 2.3466 - accuracy: 0.2216 - val_loss: 2.0112 - val_accuracy: 0.3947
# Epoch 5/75
# 19/19 [==============================] - 91s 5s/step - loss: 2.0998 - accuracy: 0.3110 - val_loss: 1.7285 - val_accuracy: 0.4753
# Epoch 6/75
# 19/19 [==============================] - 91s 5s/step - loss: 2.0154 - accuracy: 0.3368 - val_loss: 1.6237 - val_accuracy: 0.5033
# Epoch 7/75
# 19/19 [==============================] - 91s 5s/step - loss: 1.7942 - accuracy: 0.4313 - val_loss: 1.4170 - val_accuracy: 0.5493
# Epoch 8/75
# 19/19 [==============================] - 91s 5s/step - loss: 1.7715 - accuracy: 0.4244 - val_loss: 1.4068 - val_accuracy: 0.5757
# Epoch 9/75
# 19/19 [==============================] - 91s 5s/step - loss: 1.7303 - accuracy: 0.4416 - val_loss: 1.3461 - val_accuracy: 0.6151
# Epoch 10/75
# 19/19 [==============================] - 91s 5s/step - loss: 1.6260 - accuracy: 0.4485 - val_loss: 1.3387 - val_accuracy: 0.5987
# Epoch 11/75
# 19/19 [==============================] - 91s 5s/step - loss: 1
75
# 19/19 [==============================] - 90s 5s/step - loss: 0.8343 - accuracy: 0.7285 - val_loss: 0.4944 - val_accuracy: 0.8503
# Epoch 39/75
# 19/19 [==============================] - 91s 5s/step - loss: 0.8296 - accuracy: 0.7148 - val_loss: 0.4688 - val_accuracy: 0.8536
# Epoch 40/75
# 19/19 [==============================] - 91s 5s/step - loss: 0.7696 - accuracy: 0.7302 - val_loss: 0.3973 - val_accuracy: 0.8734
# Epoch 41/75
# 19/19 [==============================] - 91s 5s/step - loss: 0.7562 - accuracy: 0.7268 - val_loss: 0.4390 - val_accuracy: 0.8602
# Epoch 42/75
# 19/19 [==============================] - 91s 5s/step - loss: 0.8166 - accuracy: 0.7062 - val_loss: 0.5981 - val_accuracy: 0.7862
# Epoch 43/75
# 19/19 [==============================] - 91s 5s/step - loss: 0.7563 - accuracy: 0.7182 - val_loss: 0.4071 - val_accuracy: 0.8865
# Epoch 44/75
# 19/19 [==============================] - 99s 5s/step - loss: 0.7124 - accuracy: 0.7388 - val_loss: 0.3768 - val_accuracy: 0.8914
# Epoch 45/75
# 19/19 [==============================] - 91s 5s/step - loss: 0.6258 - accuracy: 0.7715 - val_loss: 0.3320 - val_accuracy: 0.9030
# Epoch 46/75
# 19/19 [==============================] - 91s 5s/step - loss: 0.6651 - accuracy: 0.7543 - val_loss: 0.3827 - val_accuracy: 0.8832
# Epoch 47/75
# 19/19 [==============================] - 91s 5s/step - loss: 0.7128 - accuracy: 0.7371 - val_loss: 0.3545 - val_accuracy: 0.9013
# Epoch 48/75
# 19/19 [==============================] - 91s 5s/step - loss: 0.6992 - accuracy: 0.7680 - val_loss: 0.3837 - val_accuracy: 0.8734
# Epoch 49/75
# 19/19 [==============================] - 91s 5s/step - loss: 0.7772 - accuracy: 0.7423 - val_loss: 0.5939 - val_accuracy: 0.8109
# Epoch 50/75
# 19/19 [==============================] - 91s 5s/step - loss: 0.6632 - accuracy: 0.7629 - val_loss: 0.4077 - val_accuracy: 0.8503
# Epoch 51/75
# 19/19 [==============================] - 100s 5s/step - loss: 0.6774 - accuracy: 0.7646 - val_loss: 0.3838 - val_accuracy: 0.8816
# Epoch 52/75
# 19/19 [==============================] - 91s 5s/step - loss: 0.7087 - accuracy: 0.7595 - val_loss: 0.3818 - val_accuracy: 0.8849
# Epoch 53/75
# 19/19 [==============================] - 92s 5s/step - loss: 0.6673 - accuracy: 0.7796 - val_loss: 0.3120 - val_accuracy: 0.8964
# Epoch 54/75
# 19/19 [==============================] - 91s 5s/step - loss: 0.5684 - accuracy: 0.7990 - val_loss: 0.2795 - val_accuracy: 0.9161
# Epoch 55/75
# 19/19 [==============================] - 98s 5s/step - loss: 0.5663 - accuracy: 0.8024 - val_loss: 0.2596 - val_accuracy: 0.9227
# Epoch 56/75
# 19/19 [==============================] - 91s 5s/step - loss: 0.5424 - accuracy: 0.8196 - val_loss: 0.2796 - val_accuracy: 0.9095
# Epoch 57/75
# 19/19 [==============================] - 90s 5s/step - loss: 0.6198 - accuracy: 0.7732 - val_loss: 0.3428 - val_accuracy: 0.8964
# Epoch 58/75
# 19/19 [==============================] - 91s 5s/step - loss: 0.5335 - accuracy: 0.8024 - val_loss: 0.2381 - val_accuracy: 0.9293
# Epoch 59/75
# 19/19 [==============================] - 91s 5s/step - loss: 0.5802 - accuracy: 0.7887 - val_loss: 0.3112 - val_accuracy: 0.9145
# Epoch 60/75
# 19/19 [==============================] - 90s 5s/step - loss: 0.6171 - accuracy: 0.7869 - val_loss: 0.3038 - val_accuracy: 0.9194
# Epoch 61/75
# 19/19 [==============================] - 90s 5s/step - loss: 0.5599 - accuracy: 0.8179 - val_loss: 0.2756 - val_accuracy: 0.9145
# Epoch 62/75
# 19/19 [==============================] - 90s 5s/step - loss: 0.4813 - accuracy: 0.8299 - val_loss: 0.2192 - val_accuracy: 0.9375
# Epoch 63/75
# 19/19 [==============================] - 99s 5s/step - loss: 0.5705 - accuracy: 0.7784 - val_loss: 0.2621 - val_accuracy: 0.9128
# Epoch 64/75
# 19/19 [==============================] - 91s 5s/step - loss: 0.5431 - accuracy: 0.8213 - val_loss: 0.2161 - val_accuracy: 0.9326
# Epoch 65/75
# 19/19 [==============================] - 90s 5s/step - loss: 0.5586 - accuracy: 0.7973 - val_loss: 0.3402 - val_accuracy: 0.8816
# Epoch 66/75
# 19/19 [==============================] - 90s 5s/step - loss: 0.5156 - accuracy: 0.8247 - val_loss: 0.2634 - val_accuracy: 0.9293
# Epoch 67/75
# 19/19 [==============================] - 90s 5s/step - loss: 0.4839 - accuracy: 0.8282 - val_loss: 0.2379 - val_accuracy: 0.9211
# Epoch 68/75
# 19/19 [==============================] - 101s 5s/step - loss: 0.5457 - accuracy: 0.8158 - val_loss: 0.2142 - val_accuracy: 0.9326
# Epoch 69/75
# 19/19 [==============================] - 90s 5s/step - loss: 0.5358 - accuracy: 0.8024 - val_loss: 0.2429 - val_accuracy: 0.9408
# Epoch 70/75
# 19/19 [==============================] - 98s 5s/step - loss: 0.4885 - accuracy: 0.8247 - val_loss: 0.2141 - val_accuracy: 0.9359
# Epoch 71/75
# 19/19 [==============================] - 91s 5s/step - loss: 0.5069 - accuracy: 0.8110 - val_loss: 0.1801 - val_accuracy: 0.9424
# Epoch 72/75
# 19/19 [==============================] - 91s 5s/step - loss: 0.4943 - accuracy: 0.8179 - val_loss: 0.2026 - val_accuracy: 0.9408
# Epoch 73/75
# 19/19 [==============================] - 91s 5s/step - loss: 0.4784 - accuracy: 0.8247 - val_loss: 0.2469 - val_accuracy: 0.9112
# Epoch 74/75
# 19/19 [==============================] - 91s 5s/step - loss: 0.4989 - accuracy: 0.8127 - val_loss: 0.2064 - val_accuracy: 0.9441
# Epoch 75/75
# 19/19 [==============================] - 92s 5s/step - loss: 0.5235 - accuracy: 0.8179 - val_loss: 0.2269 - val_accuracy: 0.9375

# %%
# Plotting the training vs validation accuracy and training vs validation loss over the epochs.
acc = train.history['accuracy']
val_acc = train.history['val_accuracy']
loss = train.history['loss']
val_loss = train.history['val_loss']
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, 'b', label='Training accurarcy')
plt.plot(epochs, val_acc, 'r', label='Validation accurarcy')
plt.title('Training and Validation accurarcy')
plt.legend()=
plt.figure()
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and Validation loss')
plt.legend()
plt.show()

# %%
# Save entire model with optimizer, architecture, weights and training configuration.
from keras.models import load_model
model.save('leaf.h5')

# %%
# Save model weights.
from keras.models import load_model
model.save_weights('leaf_weights.h5')

# %%
# Get classes of model trained on
classes = train_generator.class_indices
classes
# Out:
# {'Alpinia Galanga (Rasna)': 0,
#  'Amaranthus Viridis (Arive-Dantu)': 1,
#  'Azadirachta Indica (Neem)': 2,
#  'Basella Alba (Basale)': 3,
#  'Carissa Carandas (Karanda)': 4,
#  'Ficus Auriculata (Roxburgh fig)': 5,
#  'Hibiscus Rosa-sinensis': 6,
#  'Jasminum (Jasmine)': 7,
#  'Mangifera Indica (Mango)': 8,
#  'Mentha (Mint)': 9,
#  'Murraya Koenigii (Curry)': 10,
#  'Nerium Oleander (Oleander)': 11,
#  'Nyctanthes Arbor-tristis (Parijata)': 12,
#  'Ocimum Tenuiflorum (Tulsi)': 13,
#  'Piper Betle (Betel)': 14,
#  'Plectranthus Amboinicus (Mexican Mint)': 15,
#  'Punica Granatum (Pomegranate)': 16,
#  'Santalum Album (Sandalwood)': 17}

# %%
# Loading model and predict.
from keras.models import load_model
model=load_model('leaf.h5')

Classes = ['Alpinia Galanga (Rasna)',
 'Amaranthus Viridis (Arive-Dantu)',
 'Azadirachta Indica (Neem)',
 'Basella Alba (Basale)',
 'Carissa Carandas (Karanda)',
 'Ficus Auriculata (Roxburgh fig)',
 'Hibiscus Rosa-sinensis',
 'Jasminum (Jasmine)',
 'Mangifera Indica (Mango)',
 'Mentha (Mint)',
 'Murraya Koenigii (Curry)',
 'Nerium Oleander (Oleander)',
 'Nyctanthes Arbor-tristis (Parijata)',
 'Ocimum Tenuiflorum (Tulsi)',
 'Piper Betle (Betel)',
 'Plectranthus Amboinicus (Mexican Mint)',
 'Punica Granatum (Pomegranate)',
 'Santalum Album (Sandalwood)']

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
# Pre-Processing test data same as train data.
img_width = 256
img_height = 256
# Define a function to preprocess the image for model prediction.
def prepare(img_path):
    img = image.load_img(img_path, target_size=(256, 256))
    x = image.img_to_array(img)
    x = x / 255
    return np.expand_dims(x, axis=0)
# Predict the class of test image
result = model.predict(
    [prepare("/content/drive/MyDrive/Segmented Medicinal Leaf Images/Test Data/Artocarpus Heterophyllus (Jackfruit)/AH-S-001.jpg")])
predicted_class = np.argmax(result)

#Load and display the test image
plant = image.load_img(
    "/content/drive/MyDrive/Segmented Medicinal Leaf Images/Test Data/Artocarpus Heterophyllus (Jackfruit)/AH-S-001.jpg", target_size=(256, 256))
plt.imshow(plant)

# Print the predicted class name
print(Classes[predicted_class])
# Out:
# 1/1 [==============================] - 0s 145ms/step
# Ocimum Tenuiflorum (Tulsi)
